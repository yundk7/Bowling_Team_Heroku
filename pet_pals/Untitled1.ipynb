# %%
import pandas as pd
from sqlalchemy import *#create_engine,Table
import numpy as np
import random
import datetime
from datetime import timedelta

# %%
con = create_engine("postgres://qcumacnfmicopw:c700fed529373aa3b54a62168e0914d2a0d1d5b458aa965d4aea319662c6ed97@ec2-174-129-27-158.compute-1.amazonaws.com:5432/d5koeu8hgsrr65")

# %%
con.table_names()
# Out:
# ['허만', '윤동규', 'members', '곽동준', '조재현']

# %%
tables = con.table_names()

# %%
df = pd.read_sql("곽동준",con)
df
# Out:
#   name password 2019-12-04
# 0  곽동준     1213       ,301

# %%
members = pd.read_sql("members",con)
members["name"]
# Out:
# 0      최현철
# 1      석정욱
# 2      김현숙
# 3      김연정
# 4      박연수
# 5       허만
# 6      조재현
# 7      김민선
# 8      노은주
# 9      김영석
# 10     육경훈
# 11     안서연
# 12     장소현
# 13     평복재
# 14     곽동준
# 15     김태훈
# 16     홍기림
# 17     유수준
# 18     홍혜란
# 19     김대진
# 20     박지혜
# 21     이윤용
# 22     김정은
# 23     배현호
# 24     황만규
# 25     안형주
# 26     김지훈
# 27     곽승준
# 28     백민수
# 29     안기호
#       ...
# 37     차주천
# 38     김재훈
# 39     유지혜
# 40     김효진
# 41     한가을
# 42     오석현
# 43     서인애
# 44     박민정
# 45     전상일
# 46     정현암
# 47     최강석
# 48    이민우2
# 49     박태원
# 50     김윤성
# 51     김유진
# 52     윤용석
# 53     이민재
# 54     최승훈
# 55     조성환
# 56     오지호
# 57     강병호
# 58     곽윤서
# 59     김준태
# 60     김태용
# 61     김태성
# 62     박명우
# 63     이하늘
# 64     구창회
# 65     배영한
# 66     윤동규
# Name: name, Length: 67, dtype: object

# %%
df = pd.DataFrame()
for name in list(members["name"]):
    try:
        apnd = pd.read_sql(name,con)
        df = pd.concat([df,apnd])
    except:
        print(f"{name} not found")
df
# Out:
# 최현철 not found
# 석정욱 not found
# 김현숙 not found
# 김연정 not found
# 박연수 not found
# 김민선 not found
# 노은주 not found
# 김영석 not found
# 육경훈 not found
# 안서연 not found
# 장소현 not found
# 평복재 not found
# 김태훈 not found
# 홍기림 not found
# 유수준 not found
# 홍혜란 not found
# 김대진 not found
# 박지혜 not found
# 이윤용 not found
# 김정은 not found
# 배현호 not found
# 황만규 not found
# 안형주 not found
# 김지훈 not found
# 곽승준 not found
# 백민수 not found
# 안기호 not found
# 송혁진 not found
# 임미화 not found
# 이민우 not found
# 양에스더 not found
# 정슬기 not found
# 권순효 not found
# 최가영 not found
# 차주천 not found
# 김재훈 not found
# 유지혜 not found
# 김효진 not found
# 한가을 not found
# 오석현 not found
# 서인애 not found
# 박민정 not found
# 전상일 not found
# 정현암 not found
# 최강석 not found
# 이민우2 not found
# 박태원 not found
# 김윤성 not found
# 김유진 not found
# 윤용석 not found
# 이민재 not found
# 최승훈 not found
# 조성환 not found
# 오지호 not found
# 강병호 not found
# 곽윤서 not found
# 김준태 not found
# 김태용 not found
# 김태성 not found
# 박명우 not found
# 이하늘 not found
# 구창회 not found
# ...

# %%
df.drop(columns=["scores"],inplace = True)

# %%
df.sort_index(axis=1,ascending=False,inplace=True)

# %%
df
# Out:
#      2019-12-24                                  2019-12-04
# name
# 허만          NaN                                        ,300
# 조재현         NaN                                        ,141
# 곽동준         NaN                         ,301,119,130,97,156
# 윤동규        ,150  ,123,124,100,101,300,102,200,102,300,19,12

# %%
df["scores"] = df.astype(str).sum(axis=1)
df
# Out:
#      2019-12-24                                  2019-12-04  \
# name
# 허만          NaN                                        ,300
# 조재현         NaN                                        ,141
# 곽동준         NaN                         ,301,119,130,97,156
# 윤동규        ,150  ,123,124,100,101,300,102,200,102,300,19,12
#
#                                               scores
# name
# 허만                                           nan,300
# 조재현                                          nan,141
# 곽동준                           nan,301,119,130,97,156
# 윤동규   ,150,123,124,100,101,300,102,200,102,300,19,12

# %%
df.iloc[:,1:100]
# Out:
#   password    2019-12-04                scores
# 0     0823          ,300  허만0823,300허만0823,300
# 0     0226          ,141  허만0823,300허만0823,300
# 0     1213          ,301  허만0823,300허만0823,300
# 0     1234  ,123,124,100  허만0823,300허만0823,300

# %%
df.drop(columns=["scores"],inplace =True)

# %%
df.set_index("name",inplace = True)

# %%
df["scores"] = df["scores"].str.split(",")

# %%
df["scores"] = df.apply(lambda x: [int(i) for i in x["scores"]],axis=1)

# %%
df
# Out:
#                     scores password    2019-12-04
# name
# 허만              [823, 300]     0823          ,300
# 조재현             [226, 141]     0226          ,141
# 곽동준             [213, 301]     1213          ,301
# 윤동규   [234, 123, 124, 100]     1234  ,123,124,100

# %%
df.sort_index(axis = 1, ascending=False, inplace = True)
df
# Out:
#                scores password    2019-12-04
# name
# 허만            823,300     0823          ,300
# 조재현           226,141     0226          ,141
# 곽동준           213,301     1213          ,301
# 윤동규   234,123,124,100     1234  ,123,124,100

# %%
df["scores"]=df.sum(axis=1).str[1:]
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-189-fdf08193d198> in <module>
# ----> 1 df["scores"]=df.sum(axis=1).str[1:]
#       2 df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     169             # we're accessing the attribute of the class, i.e., Dataset.geo
#     170             return self._accessor
# --> 171         accessor_obj = self._accessor(obj)
# ...

# %%
df["scores"] = df.iloc[:,2:5000].sum(axis=1)
df
# Out:
#   name password    2019-12-04                                scores
# 0   허만     0823          ,300                          ,300,300,300
# 0  조재현     0226          ,141                          ,141,141,141
# 0  곽동준     1213          ,301                          ,301,301,301
# 0  윤동규     1234  ,123,124,100  ,123,124,100,123,124,100,123,124,100

# %%
ind = pd.read_sql("윤동규",con)
ind
# Out:
#   name password 2019-12-03
# 0  윤동규     0000       ,123

# %%
df = pd.read_sql("members",con)
df
# Out:
#     name  gender  DoB  DoE
# 0    최현철     NaN  NaN  NaN
# 1    석정욱     NaN  NaN  NaN
# 2    김현숙     NaN  NaN  NaN
# 3    김연정     NaN  NaN  NaN
# 4    박연수     NaN  NaN  NaN
# 5     허만     NaN  NaN  NaN
# 6    조재현     NaN  NaN  NaN
# 7    김민선     NaN  NaN  NaN
# 8    노은주     NaN  NaN  NaN
# 9    김영석     NaN  NaN  NaN
# 10   육경훈     NaN  NaN  NaN
# 11   안서연     NaN  NaN  NaN
# 12   장소현     NaN  NaN  NaN
# 13   평복재     NaN  NaN  NaN
# 14   곽동준     NaN  NaN  NaN
# 15   김태훈     NaN  NaN  NaN
# 16   홍기림     NaN  NaN  NaN
# 17   유수준     NaN  NaN  NaN
# 18   홍혜란     NaN  NaN  NaN
# 19   김대진     NaN  NaN  NaN
# 20   박지혜     NaN  NaN  NaN
# 21   이윤용     NaN  NaN  NaN
# 22   김정은     NaN  NaN  NaN
# 23   배현호     NaN  NaN  NaN
# 24   황만규     NaN  NaN  NaN
# 25   안형주     NaN  NaN  NaN
# 26   김지훈     NaN  NaN  NaN
# 27   곽승준     NaN  NaN  NaN
# 28   백민수     NaN  NaN  NaN
# 29   안기호     NaN  NaN  NaN
# ..   ...     ...  ...  ...
# 37   차주천     NaN  NaN  NaN
# 38   김재훈     NaN  NaN  NaN
# ...

# %%
name="1윤동규"
if name not in list(df["name"]):
    print("fuck")
# Out:
# fuck

# %%
# name = request.form["name"]
# password = request.form["password"]
# scores = request.form["scores"]
name = "윤동규"
scores = "123,124"
scores = str(scores).replace(" ","")
# newpw = request.form["newpw"]
date = datetime.datetime.now() + datetime.timedelta(hours=5)
date = str(date.date())

# %%
df = pd.DataFrame()

# %%
df["name"] = [name]
try:
    df[date] += [scores]
except:
    df[date] = ""
    df[date]+=[scores]
df
# Out:
#   name      2019-12-03
# 0  윤동규  123,124123,124

# %%
con = create_engine("postgres://qcumacnfmicopw:c700fed529373aa3b54a62168e0914d2a0d1d5b458aa965d4aea319662c6ed97@ec2-174-129-27-158.compute-1.amazonaws.com:5432/d5koeu8hgsrr65")
try:
    regular = pd.read_sql(name,con)
except:
    regular = pd.DataFrame()
    regular["name"] = [name]
    regular[date] = regular[date] + scores
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1243                     self.dialect.do_execute(
# -> 1244                         cursor, statement, parameters, context
#    1245                     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     549     def do_execute(self, cursor, statement, parameters, context=None):
# --> 550         cursor.execute(statement, parameters)
#     551
#
# SyntaxError: syntax error at or near "윤동규"
# LINE 1: 윤동규
#         ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# ...

# %%
dropping = Table("regular",MetaData())

# %%
try:
    dropping.drop(con)
except:
    print("none")
# Out:
# none

# %%
con.table_names()
# Out:
# []

# %%
meta = MetaData(con)
meta.reflect()
meta.drop_all()
